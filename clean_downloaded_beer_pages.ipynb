# %% [markdown]
# # Clean Downloaded BeerAdvocate Pages
#
# ## Cache pages from www.beeradvocate.com locally for further scraping
#
# By: Mike Beaumier -- Fellow, Insight Data Science
#
#  - Email: [michael.beaumier@gmail.com](mailto:michael.beaumier@gmail.com)
#  - Twitter: [@jollyhrothgar](https://twitter.com/jollyhrothgar)
#  - **LinkedIn**: [Add me w/ 1 line message about our connection](https://www.linkedin.com/in/michaelbeaumier)
#
# Repositories on [github](https://www.github.com/Jollyhrothgar)
#
# This notebook is designed to clean the downloaded beer data, and generate a database + csv file.

# %%
import os
import re 
import sys
import urllib2
import pandas
import csv
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from bs4 import BeautifulSoup

# %%
def mine_file(file_name):
    '''
    Takes file_name and mines for tables containing data about beers.
    Note that the unique brewery ID must be part of the brewery's file name. 
    This step is accomplished during scraping.
    '''
    ## Extract Brewry ID
    brewery_key = -1
    matches = re.search('brewery_(\d+).html',file_name)
    if matches:
        brewery_key = matches.group(1)
    
    if brewery_key < 0:
        print "Problem extracting brewery key. Bailing out!"
        return
    f = open(file_name,'rU')
    soup = BeautifulSoup(f.read().decode('utf-8'),'lxml')
    unicode_page = soup.prettify()
    #debug
    #print 'found ',len(soup.findAll('table')),'tables.'
    
    ### Overview Information ###
    brewery_dict = {}
    
    title = soup.title.string
    title_list = title.split('|')
    brewery_name = title_list[0].strip()
    city_state_list = title_list[1].split(',')
    brewery_city = city_state_list[0].strip()
    brewery_state = city_state_list[1].strip()
    
    brewery_dict["brewery_key"] = brewery_key
    brewery_dict["brewery_name"] = brewery_name.encode('utf_8')
    brewery_dict["city"] = brewery_city.encode('utf_8')
    brewery_dict["state"] = brewery_state.encode('utf_8')
    
    tables = soup.findAll('table')
    overview_table = tables[0]
    beer_table = tables[-1]
    
    ### Get Phone Number ###
    for row in overview_table.findAll('tr'):
        #print ">",row.text
        matches = re.search('phone: (\((\d{3})\) (\d{3})-(\d{4}))',row.text)
        if matches:
            if 'brewery_phone' not in brewery_dict:
                brewery_dict['phone'] = matches.group(1).encode('utf_8')
                brewery_dict['phone_key'] = str(matches.group(2)+matches.group(3)+matches.group(4)).encode('utf_8')

    ### Getting the beer ratings, styles, etc ###
    beers = []
    beer_dicts = []
    for row in beer_table.findAll('tr'):
        beer = []
        #beer_key contains beer style key and beer name key encoded in links.
        beer_key = row.findAll('a')
        for col in row.findAll('td'):
            value = col.text
            beer.append(value)
        beers.append(beer)
        if len(beer) == 6 and 'Style' not in beer:
            #print ">>>",beer_key
            # extract beer name key
            key_matches = re.search('/beer/profile/(\d+)/(\d+)',beer_key[0]['href'])
            
            # extract beer style key
            style_matches = re.search('/beer/style/(\d+)',beer_key[1]['href'])            
            beer_key = -1
            beer_style_key = -1
            if key_matches:
                if brewery_dict['brewery_key'] != key_matches.group(1):
                    print "Brewery key mismatch, bailing out!"
                    print "Good Key 1:", brewery_dict['brewery_key']
                    print " Bad Key 2:", key_matches.group(1)
                    return
                beer_key = key_matches.group(2)
            if style_matches:
                beer_style_key = style_matches.group(1)
            
            ## Now we can fill our beer info!
            beer_dict = {}
            beer_dict["beer_name"] = beer[0].encode('utf_8')
            beer_dict["style_name"] = beer[1].encode('utf_8')
            beer_dict["style_key"] = beer_style_key
            beer_dict["beer_name_key"] = beer_key
            beer_dict["abv"] = beer[2].encode('utf_8')
            beer_dict["avg_score"] = beer[3].encode('utf_8')
            rating = beer[4].encode('utf_8')
            clean_rating = ''.join(e for e in rating if e.isdigit() or e == '.')
            beer_dict["ratings_count"] = clean_rating
            beer_dict["bros_score"] = beer[5].encode('utf_8')
            beer_dicts.append(beer_dict)
    # debug
    # print "Brewery Summary: ",brewery_dict['brewery_name']
    
    # debug
    #for k,v in brewery_dict.iteritems():
    #    print k,v
    
    return_dict_list = []
    
    for beer in beer_dicts:
        one_beer_dict = dict(brewery_dict)
        for k,v in beer.iteritems():
            if k not in one_beer_dict:
                one_beer_dict[k] = v
        return_dict_list.append(one_beer_dict)
    
    print "Processed:",len(return_dict_list),"beers. Brewery key:",brewery_dict["brewery_key"]
    f.close()
    return return_dict_list

# %%
mine_file('./current_data/11580/brewery_11580.html')
# Out:
# Processed: 19 beers. Brewery key: 11580
# [{'abv': '5.40',
#   'avg_score': '2.78',
#   'beer_name': 'Amber Ale',
#   'beer_name_key': '27980',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '21',
#   'state': 'CA',
#   'style_key': '128',
#   'style_name': 'American Amber / Red Ale'},
#  {'abv': '7.10',
#   'avg_score': '3.88',
#   'beer_name': 'Black IPA',
#   'beer_name_key': '61868',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '4',
#   'state': 'CA',
#   'style_key': '175',
#   'style_name': 'American Black Ale'},
#  {'abv': '6.00',
#   'avg_score': '3.46',
#   'beer_name': 'Breakfast Stout',
#   'beer_name_key': '95870',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '2',
#   'state': 'CA',
#   'style_key': '158',
#   'style_name': 'American Stout'},
#  {'abv': '7.00',
#   'avg_score': '2.84',
#   'beer_name': 'Casinos IPA',
#   'beer_name_key': '97403',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '9',
#   'state': 'CA',
#   'style_key': '150',
#   'style_name': 'English India Pale Ale (IPA)'},
#  {'abv': '6.50',
#   'avg_score': '-',
#   'beer_name': 'Chai Milk Stout',
#   'beer_name_key': '199476',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '1',
#   'state': 'CA',
#   'style_key': '82',
#   'style_name': 'Milk / Sweet Stout'},
#  {'abv': '5.00',
#   'avg_score': '3.29',
#   'beer_name': 'Devout Stout',
#   'beer_name_key': '31177',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '69',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '51',
#   'state': 'CA',
#   'style_key': '158',
#   'style_name': 'American Stout'},
#  {'abv': '6.70',
#   'avg_score': '3.78',
#   'beer_name': 'Fresh Hopped Black IPA',
#   'beer_name_key': '85227',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '2',
#   'state': 'CA',
#   'style_key': '175',
#   'style_name': 'American Black Ale'},
#  {'abv': '5.00',
#   'avg_score': '-',
#   'beer_name': 'Fresh Hopped Brown Ale',
#   'beer_name_key': '203036',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '0',
#   'state': 'CA',
#   'style_key': '73',
#   'style_name': 'American Brown Ale'},
#  {'abv': '8.70',
#   'avg_score': '3.4',
#   'beer_name': 'Fucking Breakfast Stout',
#   'beer_name_key': '156309',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '1',
#   'state': 'CA',
#   'style_key': '157',
#   'style_name': 'American Double / Imperial Stout'},
#  {'abv': '6.20',
#   'avg_score': '3.18',
#   'beer_name': "Ginger's Winter Warmer",
#   'beer_name_key': '48111',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '8',
#   'state': 'CA',
#   'style_key': '47',
#   'style_name': 'Winter Warmer'},
#  {'abv': '8.00',
#   'avg_score': '2.89',
#   'beer_name': 'Imperial Stout',
#   'beer_name_key': '48732',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '2',
#   'state': 'CA',
#   'style_key': '84',
#   'style_name': 'Russian Imperial Stout'},
#  {'abv': '7.50',
#   'avg_score': '2.65',
#   'beer_name': 'India Pale Ale',
#   'beer_name_key': '27981',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '63',
#   'state': 'CA',
#   'style_key': '116',
#   'style_name': 'American IPA'},
#  {'abv': '8.50',
#   'avg_score': '3.3',
#   'beer_name': 'Nicky 666',
#   'beer_name_key': '48177',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '2',
#   'state': 'CA',
#   'style_key': '128',
#   'style_name': 'American Amber / Red Ale'},
#  {'abv': '5.40',
#   'avg_score': '3.17',
#   'beer_name': 'Organic Dread Brown Ale',
#   'beer_name_key': '31146',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '31',
#   'state': 'CA',
#   'style_key': '73',
#   'style_name': 'American Brown Ale'},
#  {'abv': '5.50',
#   'avg_score': '3.19',
#   'beer_name': 'Pale Ale',
#   'beer_name_key': '27964',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '28',
#   'state': 'CA',
#   'style_key': '54',
#   'style_name': 'Belgian Pale Ale'},
#  {'abv': '5.40',
#   'avg_score': '3.12',
#   'beer_name': "People's Porter",
#   'beer_name_key': '46505',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '29',
#   'state': 'CA',
#   'style_key': '159',
#   'style_name': 'American Porter'},
#  {'abv': '5.40',
#   'avg_score': '3.8',
#   'beer_name': 'Thy Twisted Sister',
#   'beer_name_key': '81565',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '3',
#   'state': 'CA',
#   'style_key': '158',
#   'style_name': 'American Stout'},
#  {'abv': '9.00',
#   'avg_score': '-',
#   'beer_name': 'Westside Abbey',
#   'beer_name_key': '203037',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '0',
#   'state': 'CA',
#   'style_key': '78',
#   'style_name': 'American Strong Ale'},
#  {'abv': '5.40',
#   'avg_score': '2.99',
#   'beer_name': 'Wilder Wheat',
#   'beer_name_key': '33853',
#   'brewery_key': '11580',
#   'brewery_name': 'Santa Cruz Mountain Brewing',
#   'bros_score': '-',
#   'city': 'Santa Cruz',
#   'phone': '(831) 425-4900',
#   'phone_key': '8314254900',
#   'ratings_count': '19',
#   'state': 'CA',
#   'style_key': '93',
#   'style_name': 'American Pale Wheat Ale'}]

# %%
def load_brewery_file_list(filelist):
    '''
    Given a list of newline separated file names, read each file name and store in an array.
    Return this array.
    '''
    f = open(filelist,'rU')
    files = []
    for file in f:
        s_file = file.rstrip('\n\r')
        files.append(s_file)
    print "loaded",len(files),"breweries"
    return files

# %%
def main():
    print "called main!"
    file_list = load_brewery_file_list('./lists/local_brewery_list.txt')
    beer_data_list = []
    for beer_file in file_list:
        beers = mine_file(beer_file)
        if beers:
            for beer in beers:
                beer_data_list.append(beer)
    keys = beer_data_list[0].keys()
    with open('./clean_data_csv/brewery_information.csv','wb') as output_file:
        dict_writer = csv.DictWriter(output_file,keys)
        dict_writer.writeheader()
        dict_writer.writerows(beer_data_list)
        output_file.close()
        
    print "all finished!"
    return

# %%
if __name__=='__main__':
    print "Boilerplate call to main"
    main()
# Out:
# Boilerplate call to main
# called main!
# loaded 595 breweries
# Processed: 0 beers. Brewery key: 42860
# Processed: 37 beers. Brewery key: 10046
# Processed: 13 beers. Brewery key: 10087
# Processed: 35 beers. Brewery key: 1011
# Processed: 5 beers. Brewery key: 1012
# Processed: 7 beers. Brewery key: 1015
# Processed: 12 beers. Brewery key: 1016
# Processed: 11 beers. Brewery key: 1018
# Processed: 37 beers. Brewery key: 10583
# Processed: 4 beers. Brewery key: 10626
# Processed: 21 beers. Brewery key: 10707
# Processed: 3 beers. Brewery key: 11017
# Processed: 3 beers. Brewery key: 11084
# Processed: 25 beers. Brewery key: 112
# Processed: 11 beers. Brewery key: 11342
# Processed: 20 beers. Brewery key: 11466
# Processed: 5 beers. Brewery key: 11474
# Processed: 19 beers. Brewery key: 11580
# Processed: 2 beers. Brewery key: 1196
# Processed: 16 beers. Brewery key: 12164
# Processed: 17 beers. Brewery key: 12351
# Processed: 19 beers. Brewery key: 12402
# Processed: 19 beers. Brewery key: 12788
# Processed: 36 beers. Brewery key: 13065
# Brewery key mismatch, bailing out!
# Good Key 1: 32556
#  Bad Key 2: 1337
# Processed: 12 beers. Brewery key: 13450
# Processed: 20 beers. Brewery key: 13524
# Processed: 34 beers. Brewery key: 13839
# Processed: 7 beers. Brewery key: 13973
# Processed: 183 beers. Brewery key: 140
# Processed: 31 beers. Brewery key: 14064
# Processed: 2 beers. Brewery key: 14551
# Processed: 1 beers. Brewery key: 146
# Processed: 187 beers. Brewery key: 147
# Processed: 52 beers. Brewery key: 14936
# Processed: 16 beers. Brewery key: 1497
# Processed: 2 beers. Brewery key: 15063
# Processed: 12 beers. Brewery key: 15240
# Processed: 16 beers. Brewery key: 1528
# Processed: 6 beers. Brewery key: 15314
# Processed: 9 beers. Brewery key: 15327
# Processed: 1 beers. Brewery key: 1538
# Brewery key mismatch, bailing out!
# Good Key 1: 11329
#  Bad Key 2: 1550
# Brewery key mismatch, bailing out!
# Good Key 1: 1559
#  Bad Key 2: 1551
# Processed: 11 beers. Brewery key: 15886
# Processed: 57 beers. Brewery key: 16048
# Processed: 6 beers. Brewery key: 16076
# Processed: 21 beers. Brewery key: 1627
# Processed: 29 beers. Brewery key: 16270
# Processed: 9 beers. Brewery key: 16385
# Processed: 56 beers. Brewery key: 16393
# Processed: 1 beers. Brewery key: 16453
# Processed: 7 beers. Brewery key: 16826
# Processed: 4 beers. Brewery key: 16827
# Processed: 64 beers. Brewery key: 16843
# Processed: 137 beers. Brewery key: 16866
# Processed: 12 beers. Brewery key: 1691
# Processed: 2 beers. Brewery key: 17048
# Processed: 18 beers. Brewery key: 17139
# Processed: 57 beers. Brewery key: 17271
# Processed: 31 beers. Brewery key: 17281
# Processed: 9 beers. Brewery key: 1729
# Processed: 12 beers. Brewery key: 17891
# Processed: 8 beers. Brewery key: 17945
# Processed: 1 beers. Brewery key: 17961
# Processed: 12 beers. Brewery key: 17962
# Processed: 6 beers. Brewery key: 17963
# Processed: 24 beers. Brewery key: 17988
# Processed: 5 beers. Brewery key: 18079
# Processed: 16 beers. Brewery key: 18139
# Processed: 38 beers. Brewery key: 18149
# Processed: 20 beers. Brewery key: 18258
# Processed: 2 beers. Brewery key: 18368
# Processed: 6 beers. Brewery key: 18382
# Processed: 4 beers. Brewery key: 18874
# Processed: 37 beers. Brewery key: 19202
# Processed: 25 beers. Brewery key: 19252
# Processed: 51 beers. Brewery key: 193
# Processed: 18 beers. Brewery key: 19402
# Processed: 4 beers. Brewery key: 19424
# Processed: 3 beers. Brewery key: 19553
# Processed: 6 beers. Brewery key: 19570
# Processed: 3 beers. Brewery key: 19582
# Processed: 1 beers. Brewery key: 19666
# Processed: 10 beers. Brewery key: 19812
# Processed: 14 beers. Brewery key: 19890
# Processed: 214 beers. Brewery key: 199
# Brewery key mismatch, bailing out!
# Good Key 1: 2516
#  Bad Key 2: 200
# Processed: 4 beers. Brewery key: 20389
# Processed: 16 beers. Brewery key: 2042
# Processed: 48 beers. Brewery key: 20430
# Processed: 12 beers. Brewery key: 205
# Processed: 1 beers. Brewery key: 20647
# Processed: 6 beers. Brewery key: 20707
# Processed: 9 beers. Brewery key: 20757
# Processed: 3 beers. Brewery key: 20878
# Processed: 6 beers. Brewery key: 2089
# Processed: 2 beers. Brewery key: 21012
# Processed: 84 beers. Brewery key: 21092
# Processed: 10 beers. Brewery key: 21316
# Processed: 2 beers. Brewery key: 21421
# Processed: 13 beers. Brewery key: 21445
# Processed: 58 beers. Brewery key: 21448
# Processed: 16 beers. Brewery key: 21449
# Processed: 11 beers. Brewery key: 2154
# Processed: 38 beers. Brewery key: 2156
# Processed: 1 beers. Brewery key: 21623
# Processed: 49 beers. Brewery key: 21651
# Processed: 1 beers. Brewery key: 21678
# Processed: 54 beers. Brewery key: 2175
# Processed: 7 beers. Brewery key: 2179
# Processed: 1 beers. Brewery key: 2180
# Processed: 19 beers. Brewery key: 21856
# Processed: 35 beers. Brewery key: 219
# Processed: 1 beers. Brewery key: 21940
# Processed: 19 beers. Brewery key: 2195
# Processed: 11 beers. Brewery key: 2199
# Processed: 95 beers. Brewery key: 220
# Processed: 65 beers. Brewery key: 22065
# Processed: 85 beers. Brewery key: 2210
# Processed: 2 beers. Brewery key: 22170
# Processed: 7 beers. Brewery key: 22230
# Processed: 125 beers. Brewery key: 22412
# Processed: 1 beers. Brewery key: 2250
# Processed: 44 beers. Brewery key: 22598
# Processed: 72 beers. Brewery key: 22610
# Processed: 35 beers. Brewery key: 22622
# Processed: 16 beers. Brewery key: 22937
# Processed: 43 beers. Brewery key: 23200
# Processed: 58 beers. Brewery key: 2321
# Processed: 50 beers. Brewery key: 23347
# Processed: 38 beers. Brewery key: 23459
# Processed: 36 beers. Brewery key: 2352
# Processed: 8 beers. Brewery key: 23628
# Processed: 28 beers. Brewery key: 23640
# Processed: 19 beers. Brewery key: 23641
# Processed: 2 beers. Brewery key: 23642
# Processed: 4 beers. Brewery key: 23647
# Processed: 21 beers. Brewery key: 23697
# Processed: 3 beers. Brewery key: 23698
# Processed: 1 beers. Brewery key: 23725
# Processed: 25 beers. Brewery key: 24026
# Processed: 11 beers. Brewery key: 2414
# Processed: 9 beers. Brewery key: 24147
# Processed: 110 beers. Brewery key: 2447
# Processed: 16 beers. Brewery key: 24477
# Processed: 11 beers. Brewery key: 24493
# Processed: 5 beers. Brewery key: 24582
# Processed: 61 beers. Brewery key: 24600
# Processed: 5 beers. Brewery key: 24625
# Processed: 6 beers. Brewery key: 24657
# Processed: 59 beers. Brewery key: 24748
# Processed: 1 beers. Brewery key: 24813
# Processed: 12 beers. Brewery key: 24820
# Processed: 2 beers. Brewery key: 24824
# Processed: 15 beers. Brewery key: 24827
# Processed: 23 beers. Brewery key: 24832
# Processed: 44 beers. Brewery key: 24940
# Processed: 4 beers. Brewery key: 24952
# Processed: 19 beers. Brewery key: 25032
# Processed: 7 beers. Brewery key: 25208
# Processed: 7 beers. Brewery key: 25254
# Processed: 8 beers. Brewery key: 25256
# Processed: 39 beers. Brewery key: 25260
# Processed: 4 beers. Brewery key: 25338
# Processed: 5 beers. Brewery key: 25430
# Processed: 6 beers. Brewery key: 25432
# Processed: 21 beers. Brewery key: 2547
# Processed: 8 beers. Brewery key: 255
# Processed: 39 beers. Brewery key: 256
# Processed: 6 beers. Brewery key: 257
# Processed: 1 beers. Brewery key: 25770
# Processed: 40 beers. Brewery key: 25920
# Processed: 14 beers. Brewery key: 25926
# Processed: 11 beers. Brewery key: 25935
# Processed: 1 beers. Brewery key: 25944
# Processed: 31 beers. Brewery key: 25945
# Processed: 110 beers. Brewery key: 25959
# Processed: 26 beers. Brewery key: 25960
# Processed: 8 beers. Brewery key: 25976
# Processed: 3 beers. Brewery key: 26393
# Processed: 19 beers. Brewery key: 2651
# Processed: 25 beers. Brewery key: 266
# Processed: 21 beers. Brewery key: 26612
# Processed: 9 beers. Brewery key: 26626
# Processed: 39 beers. Brewery key: 26704
# Processed: 74 beers. Brewery key: 26932
# Processed: 2 beers. Brewery key: 26946
# Processed: 4 beers. Brewery key: 2698
# Processed: 62 beers. Brewery key: 2700
# Processed: 2 beers. Brewery key: 27090
# Brewery key mismatch, bailing out!
# Good Key 1: 11666
#  Bad Key 2: 2710
# Processed: 32 beers. Brewery key: 27109
# Processed: 15 beers. Brewery key: 2711
# Processed: 4 beers. Brewery key: 27117
# Processed: 15 beers. Brewery key: 27231
# Processed: 14 beers. Brewery key: 2724
# Processed: 10 beers. Brewery key: 27276
# Processed: 1 beers. Brewery key: 27277
# Processed: 31 beers. Brewery key: 27322
# Processed: 10 beers. Brewery key: 27327
# Processed: 21 beers. Brewery key: 27331
# Processed: 23 beers. Brewery key: 27378
# Processed: 114 beers. Brewery key: 2743
# Processed: 27 beers. Brewery key: 27632
# Processed: 3 beers. Brewery key: 27800
# Processed: 52 beers. Brewery key: 27922
# Processed: 3 beers. Brewery key: 27944
# Processed: 28 beers. Brewery key: 27946
# Processed: 45 beers. Brewery key: 27996
# Processed: 30 beers. Brewery key: 28
# Processed: 102 beers. Brewery key: 28019
# Processed: 13 beers. Brewery key: 28260
# Processed: 61 beers. Brewery key: 28261
# Processed: 19 beers. Brewery key: 28270
# Processed: 59 beers. Brewery key: 28657
# Processed: 3 beers. Brewery key: 28724
# Processed: 9 beers. Brewery key: 28733
# Processed: 4 beers. Brewery key: 28817
# Processed: 2 beers. Brewery key: 28819
# Processed: 18 beers. Brewery key: 28821
# Processed: 24 beers. Brewery key: 28838
# Processed: 1 beers. Brewery key: 28969
# Processed: 42 beers. Brewery key: 28994
# Processed: 1 beers. Brewery key: 2910
# Processed: 19 beers. Brewery key: 29164
# Processed: 69 beers. Brewery key: 29180
# Processed: 46 beers. Brewery key: 29200
# Processed: 28 beers. Brewery key: 29265
# Processed: 5 beers. Brewery key: 29266
# Processed: 12 beers. Brewery key: 29267
# Processed: 13 beers. Brewery key: 29315
# Processed: 12 beers. Brewery key: 29316
# Processed: 15 beers. Brewery key: 29346
# Processed: 14 beers. Brewery key: 29371
# Processed: 3 beers. Brewery key: 29441
# Processed: 64 beers. Brewery key: 29481
# Processed: 2 beers. Brewery key: 29482
# Processed: 37 beers. Brewery key: 29618
# Processed: 11 beers. Brewery key: 29714
# Processed: 5 beers. Brewery key: 29730
# Processed: 30 beers. Brewery key: 29744
# Processed: 9 beers. Brewery key: 29762
# Processed: 31 beers. Brewery key: 29767
# Processed: 7 beers. Brewery key: 29777
# Processed: 32 beers. Brewery key: 29778
# Processed: 13 beers. Brewery key: 29910
# Processed: 26 beers. Brewery key: 29911
# Processed: 24 beers. Brewery key: 30028
# Processed: 23 beers. Brewery key: 30228
# Processed: 9 beers. Brewery key: 30265
# Processed: 20 beers. Brewery key: 30283
# Processed: 6 beers. Brewery key: 30298
# Processed: 20 beers. Brewery key: 30377
# Processed: 22 beers. Brewery key: 30379
# Processed: 16 beers. Brewery key: 30407
# Processed: 59 beers. Brewery key: 30458
# Processed: 18 beers. Brewery key: 30546
# Processed: 10 beers. Brewery key: 3055
# Processed: 42 beers. Brewery key: 30584
# Processed: 23 beers. Brewery key: 30608
# Processed: 53 beers. Brewery key: 30687
# Processed: 17 beers. Brewery key: 3073
# Processed: 21 beers. Brewery key: 30740
# Processed: 21 beers. Brewery key: 30771
# Processed: 9 beers. Brewery key: 30816
# Processed: 33 beers. Brewery key: 30923
# Processed: 11 beers. Brewery key: 30982
# Processed: 5 beers. Brewery key: 31027
# Processed: 36 beers. Brewery key: 31059
# Processed: 20 beers. Brewery key: 31097
# Processed: 14 beers. Brewery key: 31117
# Processed: 19 beers. Brewery key: 31141
# Processed: 5 beers. Brewery key: 31164
# Processed: 27 beers. Brewery key: 31171
# Processed: 46 beers. Brewery key: 3120
# Processed: 45 beers. Brewery key: 31319
# Processed: 21 beers. Brewery key: 31331
# Processed: 33 beers. Brewery key: 31332
# Processed: 16 beers. Brewery key: 31363
# Processed: 21 beers. Brewery key: 31371
# Processed: 50 beers. Brewery key: 31398
# Processed: 34 beers. Brewery key: 31407
# Processed: 19 beers. Brewery key: 31554
# Processed: 32 beers. Brewery key: 31569
# Processed: 21 beers. Brewery key: 31571
# Processed: 8 beers. Brewery key: 31686
# Processed: 28 beers. Brewery key: 31688
# Processed: 6 beers. Brewery key: 31689
# Processed: 8 beers. Brewery key: 31697
# Processed: 7 beers. Brewery key: 31712
# Processed: 10 beers. Brewery key: 31730
# Processed: 27 beers. Brewery key: 31789
# Processed: 13 beers. Brewery key: 31791
# Processed: 13 beers. Brewery key: 31899
# Processed: 124 beers. Brewery key: 31987
# Processed: 15 beers. Brewery key: 32038
# Processed: 16 beers. Brewery key: 32063
# Processed: 16 beers. Brewery key: 32087
# Processed: 66 beers. Brewery key: 32092
# Processed: 17 beers. Brewery key: 32140
# Processed: 20 beers. Brewery key: 32161
# Processed: 32 beers. Brewery key: 32258
# Processed: 9 beers. Brewery key: 32270
# Processed: 24 beers. Brewery key: 32280
# Processed: 3 beers. Brewery key: 3232
# Processed: 35 beers. Brewery key: 32541
# Processed: 17 beers. Brewery key: 32705
# Processed: 18 beers. Brewery key: 32767
# Processed: 4 beers. Brewery key: 32796
# Processed: 18 beers. Brewery key: 32831
# Processed: 36 beers. Brewery key: 32922
# Processed: 16 beers. Brewery key: 32930
# Processed: 122 beers. Brewery key: 32931
# Processed: 6 beers. Brewery key: 32941
# Processed: 8 beers. Brewery key: 32943
# Processed: 3 beers. Brewery key: 32974
# Processed: 40 beers. Brewery key: 33018
# Processed: 4 beers. Brewery key: 33019
# Processed: 34 beers. Brewery key: 33027
# Processed: 2 beers. Brewery key: 33105
# Processed: 8 beers. Brewery key: 33111
# Processed: 8 beers. Brewery key: 33176
# Processed: 60 beers. Brewery key: 33181
# Processed: 6 beers. Brewery key: 33199
# Processed: 22 beers. Brewery key: 33224
# Processed: 32 beers. Brewery key: 33278
# Processed: 19 beers. Brewery key: 33347
# Processed: 18 beers. Brewery key: 33418
# Processed: 12 beers. Brewery key: 33428
# Processed: 9 beers. Brewery key: 33484
# Processed: 19 beers. Brewery key: 33490
# Processed: 1 beers. Brewery key: 33503
# Processed: 7 beers. Brewery key: 33532
# Processed: 10 beers. Brewery key: 33533
# Processed: 15 beers. Brewery key: 33534
# Processed: 5 beers. Brewery key: 33561
# Processed: 1 beers. Brewery key: 33777
# Processed: 41 beers. Brewery key: 33816
# Processed: 12 beers. Brewery key: 33817
# Processed: 34 beers. Brewery key: 33819
# Processed: 5 beers. Brewery key: 33821
# Processed: 30 beers. Brewery key: 33822
# Processed: 27 beers. Brewery key: 33823
# Processed: 91 beers. Brewery key: 33824
# Processed: 6 beers. Brewery key: 33846
# Processed: 11 beers. Brewery key: 33983
# Processed: 13 beers. Brewery key: 34005
# Processed: 12 beers. Brewery key: 34017
# Processed: 4 beers. Brewery key: 34023
# Processed: 24 beers. Brewery key: 34024
# Processed: 69 beers. Brewery key: 34029
# Processed: 5 beers. Brewery key: 34033
# Processed: 18 beers. Brewery key: 34034
# Processed: 27 beers. Brewery key: 34078
# Processed: 15 beers. Brewery key: 34117
# Processed: 2 beers. Brewery key: 34182
# Processed: 24 beers. Brewery key: 34193
# Processed: 25 beers. Brewery key: 34194
# Processed: 26 beers. Brewery key: 34207
# Processed: 15 beers. Brewery key: 34279
# Processed: 24 beers. Brewery key: 34282
# Processed: 12 beers. Brewery key: 34323
# Processed: 11 beers. Brewery key: 3440
# Processed: 10 beers. Brewery key: 34409
# Processed: 12 beers. Brewery key: 34441
# Processed: 55 beers. Brewery key: 34453
# Processed: 14 beers. Brewery key: 34468
# Processed: 13 beers. Brewery key: 3448
# Processed: 17 beers. Brewery key: 34494
# Processed: 2 beers. Brewery key: 34516
# Processed: 21 beers. Brewery key: 34618
# Processed: 6 beers. Brewery key: 34727
# Processed: 84 beers. Brewery key: 34734
# Processed: 3 beers. Brewery key: 34782
# Processed: 32 beers. Brewery key: 35011
# Processed: 19 beers. Brewery key: 35210
# Processed: 1 beers. Brewery key: 35215
# Processed: 5 beers. Brewery key: 35220
# Processed: 4 beers. Brewery key: 35243
# Processed: 43 beers. Brewery key: 35259
# Processed: 25 beers. Brewery key: 35341
# Processed: 5 beers. Brewery key: 35403
# Processed: 7 beers. Brewery key: 35428
# Processed: 17 beers. Brewery key: 35450
# Processed: 22 beers. Brewery key: 35481
# Processed: 13 beers. Brewery key: 3585
# Processed: 13 beers. Brewery key: 35865
# Processed: 1 beers. Brewery key: 36011
# Processed: 6 beers. Brewery key: 36042
# Processed: 22 beers. Brewery key: 36135
# Processed: 9 beers. Brewery key: 36149
# Processed: 6 beers. Brewery key: 36160
# Processed: 22 beers. Brewery key: 36186
# Processed: 25 beers. Brewery key: 36428
# Processed: 59 beers. Brewery key: 36523
# Processed: 43 beers. Brewery key: 36594
# Processed: 2 beers. Brewery key: 36609
# Processed: 10 beers. Brewery key: 36610
# Processed: 6 beers. Brewery key: 36623
# Processed: 18 beers. Brewery key: 36684
# Processed: 28 beers. Brewery key: 36754
# Processed: 19 beers. Brewery key: 36812
# Processed: 10 beers. Brewery key: 36815
# Processed: 48 beers. Brewery key: 36847
# Processed: 10 beers. Brewery key: 36871
# Processed: 12 beers. Brewery key: 36937
# Processed: 11 beers. Brewery key: 36948
# Processed: 18 beers. Brewery key: 36959
# Processed: 10 beers. Brewery key: 36988
# Processed: 3 beers. Brewery key: 37125
# Processed: 10 beers. Brewery key: 37126
# Processed: 11 beers. Brewery key: 37127
# Processed: 13 beers. Brewery key: 37305
# Processed: 11 beers. Brewery key: 37348
# Processed: 6 beers. Brewery key: 37371
# Processed: 2 beers. Brewery key: 37398
# Processed: 14 beers. Brewery key: 37430
# Processed: 40 beers. Brewery key: 37448
# Processed: 17 beers. Brewery key: 37451
# Processed: 4 beers. Brewery key: 3759
# Processed: 4 beers. Brewery key: 37603
# Processed: 2 beers. Brewery key: 37610
# Processed: 96 beers. Brewery key: 37625
# Processed: 33 beers. Brewery key: 37627
# Processed: 6 beers. Brewery key: 37741
# Processed: 22 beers. Brewery key: 37749
# Processed: 11 beers. Brewery key: 37759
# Processed: 34 beers. Brewery key: 3776
# Processed: 16 beers. Brewery key: 37794
# Processed: 18 beers. Brewery key: 37894
# Processed: 2 beers. Brewery key: 37969
# Processed: 1 beers. Brewery key: 38031
# Processed: 41 beers. Brewery key: 38091
# Processed: 15 beers. Brewery key: 38209
# Processed: 8 beers. Brewery key: 38229
# Processed: 9 beers. Brewery key: 38234
# Processed: 22 beers. Brewery key: 38262
# Processed: 1 beers. Brewery key: 38263
# Processed: 18 beers. Brewery key: 38282
# Processed: 29 beers. Brewery key: 38284
# Processed: 6 beers. Brewery key: 38285
# Processed: 2 beers. Brewery key: 38302
# Processed: 75 beers. Brewery key: 3835
# Processed: 21 beers. Brewery key: 38396
# Processed: 18 beers. Brewery key: 38399
# Processed: 7 beers. Brewery key: 38591
# Processed: 14 beers. Brewery key: 38614
# Processed: 4 beers. Brewery key: 38666
# Processed: 12 beers. Brewery key: 38744
# Processed: 60 beers. Brewery key: 38745
# Processed: 8 beers. Brewery key: 38828
# Processed: 5 beers. Brewery key: 38886
# Processed: 10 beers. Brewery key: 38898
# Processed: 4 beers. Brewery key: 38916
# Processed: 7 beers. Brewery key: 38933
# Processed: 3 beers. Brewery key: 38953
# Processed: 10 beers. Brewery key: 38958
# Processed: 22 beers. Brewery key: 38959
# Processed: 9 beers. Brewery key: 38960
# Processed: 9 beers. Brewery key: 38961
# Processed: 26 beers. Brewery key: 38962
# Processed: 23 beers. Brewery key: 38963
# Processed: 12 beers. Brewery key: 39137
# Processed: 12 beers. Brewery key: 3915
# Processed: 13 beers. Brewery key: 39282
# Processed: 28 beers. Brewery key: 39472
# Processed: 6 beers. Brewery key: 39490
# Processed: 84 beers. Brewery key: 396
# Processed: 18 beers. Brewery key: 3965
# Processed: 9 beers. Brewery key: 39663
# Processed: 9 beers. Brewery key: 39838
# Processed: 2 beers. Brewery key: 39855
# Processed: 3 beers. Brewery key: 39942
# Processed: 1 beers. Brewery key: 40040
# Processed: 13 beers. Brewery key: 40467
# Processed: 35 beers. Brewery key: 4051
# Processed: 22 beers. Brewery key: 40535
# Processed: 11 beers. Brewery key: 40539
# Processed: 13 beers. Brewery key: 40559
# Processed: 10 beers. Brewery key: 40632
# Processed: 12 beers. Brewery key: 40633
# Processed: 14 beers. Brewery key: 40634
# Processed: 15 beers. Brewery key: 40647
# Processed: 3 beers. Brewery key: 40741
# Processed: 3 beers. Brewery key: 40801
# Processed: 14 beers. Brewery key: 40892
# Processed: 47 beers. Brewery key: 409
# Processed: 6 beers. Brewery key: 40927
# Processed: 4 beers. Brewery key: 40977
# Processed: 1 beers. Brewery key: 41029
# Processed: 18 beers. Brewery key: 41031
# Processed: 12 beers. Brewery key: 41122
# Processed: 10 beers. Brewery key: 41123
# Processed: 2 beers. Brewery key: 41168
# Processed: 3 beers. Brewery key: 41248
# Processed: 18 beers. Brewery key: 41330
# Processed: 9 beers. Brewery key: 41427
# Processed: 26 beers. Brewery key: 41429
# Processed: 96 beers. Brewery key: 4146
# Processed: 3 beers. Brewery key: 41466
# Processed: 10 beers. Brewery key: 41472
# Processed: 8 beers. Brewery key: 41473
# Processed: 2 beers. Brewery key: 41541
# Processed: 5 beers. Brewery key: 41543
# Processed: 10 beers. Brewery key: 41584
# Processed: 7 beers. Brewery key: 41602
# Processed: 3 beers. Brewery key: 41820
# Processed: 4 beers. Brewery key: 41865
# Processed: 7 beers. Brewery key: 419
# Processed: 17 beers. Brewery key: 41927
# Processed: 4 beers. Brewery key: 41955
# Processed: 7 beers. Brewery key: 41964
# Processed: 6 beers. Brewery key: 42557
# Processed: 7 beers. Brewery key: 42559
# Processed: 15 beers. Brewery key: 42562
# Processed: 7 beers. Brewery key: 42565
# Processed: 9 beers. Brewery key: 42577
# Processed: 7 beers. Brewery key: 42654
# Processed: 8 beers. Brewery key: 42740
# Processed: 8 beers. Brewery key: 42779
# Processed: 29 beers. Brewery key: 4288
# Processed: 6 beers. Brewery key: 42930
# Processed: 1 beers. Brewery key: 42935
# Processed: 13 beers. Brewery key: 42970
# Processed: 10 beers. Brewery key: 42975
# Processed: 9 beers. Brewery key: 4300
# Processed: 9 beers. Brewery key: 43001
# Processed: 1 beers. Brewery key: 43070
# Processed: 4 beers. Brewery key: 43085
# Processed: 10 beers. Brewery key: 43119
# Processed: 17 beers. Brewery key: 43153
# Processed: 28 beers. Brewery key: 4317
# Processed: 5 beers. Brewery key: 43296
# Processed: 12 beers. Brewery key: 43348
# Processed: 1 beers. Brewery key: 4335
# Processed: 9 beers. Brewery key: 43369
# Processed: 4 beers. Brewery key: 43805
# Processed: 40 beers. Brewery key: 4410
# Processed: 22 beers. Brewery key: 4432
# Processed: 63 beers. Brewery key: 447
# Processed: 41 beers. Brewery key: 4555
# Processed: 11 beers. Brewery key: 460
# Processed: 56 beers. Brewery key: 463
# Processed: 32 beers. Brewery key: 4712
# Processed: 12 beers. Brewery key: 4742
# Processed: 1 beers. Brewery key: 485
# Processed: 3 beers. Brewery key: 4873
# Processed: 12 beers. Brewery key: 4916
# Processed: 22 beers. Brewery key: 4926
# Processed: 26 beers. Brewery key: 4950
# Processed: 4 beers. Brewery key: 5107
# Processed: 22 beers. Brewery key: 5115
# Processed: 29 beers. Brewery key: 5266
# Processed: 33 beers. Brewery key: 5337
# Processed: 14 beers. Brewery key: 5410
# Processed: 24 beers. Brewery key: 5411
# Processed: 43 beers. Brewery key: 559
# Processed: 10 beers. Brewery key: 562
# Processed: 6 beers. Brewery key: 591
# Processed: 16 beers. Brewery key: 609
# Processed: 88 beers. Brewery key: 610
# Processed: 27 beers. Brewery key: 619
# Processed: 3 beers. Brewery key: 630
# Processed: 47 beers. Brewery key: 632
# Processed: 4 beers. Brewery key: 6371
# Processed: 29 beers. Brewery key: 640
# Processed: 9 beers. Brewery key: 6421
# Processed: 9 beers. Brewery key: 6976
# Processed: 25 beers. Brewery key: 7015
# Processed: 5 beers. Brewery key: 7064
# Processed: 58 beers. Brewery key: 735
# Processed: 7 beers. Brewery key: 762
# Processed: 25 beers. Brewery key: 763
# Processed: 7 beers. Brewery key: 7685
# Processed: 16 beers. Brewery key: 803
# Processed: 42 beers. Brewery key: 812
# Processed: 10 beers. Brewery key: 845
# Processed: 14 beers. Brewery key: 8540
# Processed: 21 beers. Brewery key: 862
# Processed: 51 beers. Brewery key: 863
# Processed: 18 beers. Brewery key: 8681
# Processed: 11 beers. Brewery key: 8685
# Processed: 54 beers. Brewery key: 870
# Processed: 28 beers. Brewery key: 8818
# Processed: 26 beers. Brewery key: 882
# Processed: 15 beers. Brewery key: 8930
# Processed: 19 beers. Brewery key: 910
# Processed: 11 beers. Brewery key: 9243
# Processed: 31 beers. Brewery key: 978
# Processed: 11 beers. Brewery key: 980
# Processed: 12 beers. Brewery key: 981
# Processed: 18 beers. Brewery key: 9823
# Processed: 31 beers. Brewery key: 9914
# Processed: 6 beers. Brewery key: 9916
# all finished!
