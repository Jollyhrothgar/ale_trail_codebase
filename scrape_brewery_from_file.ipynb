# %%
import os
import re 
import sys
import urllib2
import pandas
import csv
import numpy as np
import matplotlib.pyplot as plt
from time import sleep
from bs4 import BeautifulSoup

# %%
def main():
    breweries = load_url_list('brewery_urls.txt')
    master_list = []
    #kill_if = 4
    #counter = 0
    for brewery in breweries:
        sleep(0.25)
        return_list = scrape_brewery(brewery)
        if len(return_list) != 0:
            for item in return_list:
                master_list.append(item)
        #if counter == kill_if:
        #    break
        #counter+=1
    
    ### now save the clean data to a csv ###
    keys = master_list[0].keys()
    with open('california_breweries.csv', 'wb') as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(master_list)

# %%
# Standard boilerplate to call the main() function to begin
# the program.
if __name__ == '__main__':
    main()
# Out:
# Loaded 645 breweries.
# Scraping URL:  http://www.beeradvocate.com/beer/profile/31027/
# found  4 tables.
# Brewery Summary:  http://www.beeradvocate.com/beer/profile/31027/
# Processed: 5 beers
# Scraping URL:  http://www.beeradvocate.com/beer/profile/42860/
# found  4 tables.
# Brewery Summary:  http://www.beeradvocate.com/beer/profile/42860/
# Processed: 0 beers
# Scraping URL:  http://www.beeradvocate.com/beer/profile/735/
# found  4 tables.
# Brewery Summary:  http://www.beeradvocate.com/beer/profile/735/
# Processed: 58 beers
# Scraping URL:  http://www.beeradvocate.com/beer/profile/33347/
# found  4 tables.
# Brewery Summary:  http://www.beeradvocate.com/beer/profile/33347/
# Processed: 19 beers
# Scraping URL:  http://www.beeradvocate.com/beer/profile/36135/
# found  4 tables.
# Brewery Summary:  http://www.beeradvocate.com/beer/profile/36135/
# Processed: 22 beers
# Scraping URL:  http://www.beeradvocate.com/beer/profile/41466/
# found  4 tables.
# ...
